# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold
from sklearn.metrics import mean_squared_error, make_scorer

# Load the training data
train_df = pd.read_csv('Trout_training.csv')
test_features_df = pd.read_csv('Trout_testing_features.csv')

# Convert Date_Time to datetime
train_df['Date_Time'] = pd.to_datetime(train_df['Date_Time'])
test_features_df['Date_Time'] = pd.to_datetime(test_features_df['Date_Time'])

# Extract temporal features
for df in [train_df, test_features_df]:
    df['year'] = df['Date_Time'].dt.year
    df['month'] = df['Date_Time'].dt.month
    df['day'] = df['Date_Time'].dt.day
    df['hour'] = df['Date_Time'].dt.hour
    df['day_of_year'] = df['Date_Time'].dt.dayofyear

# Pivot training data to create feature set
train_pivot = train_df.pivot_table(index='Date_Time', columns='Depth_m', values='Water_Temp_C').reset_index()
train_pivot.columns = [f"depth_{col}" if isinstance(col, float) else col for col in train_pivot.columns]
train_pivot = train_pivot.merge(train_df[['Date_Time', 'year', 'month', 'day', 'hour', 'day_of_year']].drop_duplicates(), on='Date_Time', how='left')

# Drop rows with missing values
train_pivot = train_pivot.dropna()

# Separate features and target variable
X = train_pivot.drop(columns=['Date_Time', 'depth_10.5'])  # Features excluding target depth
y = train_pivot['depth_10.5']  # Target

# Define the parameter grid for tuning
param_grid = {
    'n_estimators': [500, 1000],
    'learning_rate': [0.01, 0.05],
    'max_depth': [5, 10],
    'subsample': [0.6, 0.8],
    'colsample_bytree': [0.5, 0.8],
}

# Define the XGBoost regressor
xgb_reg = xgb.XGBRegressor(random_state=42)

# Use a nested cross-validation
inner_cv = KFold(n_splits=3, shuffle=True, random_state=42)  # Inner loop for parameter tuning
outer_cv = KFold(n_splits=5, shuffle=True, random_state=42)  # Outer loop for model evaluation

# Define the GridSearchCV with the inner cross-validation
grid_search = GridSearchCV(estimator=xgb_reg, param_grid=param_grid, scoring='neg_mean_squared_error', cv=inner_cv, n_jobs=-1, verbose=2)

# Perform the outer cross-validation with the nested structure
nested_scores = cross_val_score(grid_search, X, y, scoring='neg_mean_squared_error', cv=outer_cv, n_jobs=-1)

# Calculate mean and standard deviation of the nested scores
nested_mse_mean = -nested_scores.mean()  # Mean of MSE from cross-validation
nested_mse_std = nested_scores.std()

print(f"Nested CV MSE: Mean = {nested_mse_mean}, Std = {nested_mse_std}")

# Fit the final model on the full dataset using best parameters found
grid_search.fit(X, y)
best_model = grid_search.best_estimator_

# Prepare the test data for predictions
test_pivot = test_features_df.pivot_table(index='Date_Time', columns='Depth_m', values='Water_Temp_C').reset_index()
test_pivot.columns = [f"depth_{col}" if isinstance(col, float) else col for col in test_pivot.columns]
test_pivot = test_pivot.merge(test_features_df[['Date_Time', 'year', 'month', 'day', 'hour', 'day_of_year']].drop_duplicates(), on='Date_Time', how='left')

# Make predictions on the test set
X_test = test_pivot.drop(columns=['Date_Time'])
predictions = best_model.predict(X_test)

# Create submission dataframe
submission_df = pd.DataFrame({
    'Date_Time': test_pivot['Date_Time'],
    'Water_Temp_C': predictions
})

# Save predictions to CSV
submission_df['Date_Time'] = pd.to_datetime(submission_df['Date_Time']).dt.strftime('%m/%d/%Y %H:%M')
submission_df.to_csv('lake_trout_predictions.csv', index=False)

print("Submission file created:", submission_df.shape)
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   4.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   5.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   5.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   5.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   5.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   5.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   5.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   5.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   5.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   5.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   5.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   5.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   5.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   5.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   5.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   5.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   5.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   5.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   5.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   5.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   5.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   5.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   5.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   5.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   5.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   5.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=   9.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=   9.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=   9.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=   9.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  10.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=   9.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=   9.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  10.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  10.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  10.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  10.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  10.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  10.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  10.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  11.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  10.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  11.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  10.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  11.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  10.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  11.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  10.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  11.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  11.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  11.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  11.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  11.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  11.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  11.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  11.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  21.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  21.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  21.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  21.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  21.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  21.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  21.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  21.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  21.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  22.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  23.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  23.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  24.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  24.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  23.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  24.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  24.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  25.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  25.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  25.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  25.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  25.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  26.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  25.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  26.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  25.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  26.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  26.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  26.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  26.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   7.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   7.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   7.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   7.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   7.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   5.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   7.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  53.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  53.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  54.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  54.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  54.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  54.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  54.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  55.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  55.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  55.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  12.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  12.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  12.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  12.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  54.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  54.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  55.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  55.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  12.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  12.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  56.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  58.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  58.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  58.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  58.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  58.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  58.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  59.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  58.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  58.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  59.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  59.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  59.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  58.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  59.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time= 1.0min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=  25.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=  25.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=  26.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=  25.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=  25.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=  25.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=  25.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=  24.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=  25.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=  25.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=  26.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=  26.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=  25.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  26.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=  25.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=  26.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  24.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  26.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  25.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  25.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  24.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  25.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  26.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  26.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  24.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  25.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  26.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  25.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  25.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  25.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   7.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   7.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   8.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   7.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   7.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   7.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   8.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   7.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   7.7s[CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   7.9s
#
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   7.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   7.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   8.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   7.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   7.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   7.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   7.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   7.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   8.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   8.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   9.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   9.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   9.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=  10.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=  10.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=  10.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   9.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   9.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   9.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   9.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  52.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  52.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  52.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  52.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  52.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  53.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  52.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  52.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  51.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  52.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  14.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  14.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  14.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  14.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  14.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  14.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  49.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  12.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  50.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  49.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  48.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  49.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  49.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  49.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  51.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  50.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  49.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  49.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  48.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  51.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  48.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=  14.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  49.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  49.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  48.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  49.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  49.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  52.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  28.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  28.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  28.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  28.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  28.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  28.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  28.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  28.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  28.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  28.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  29.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  28.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  29.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  28.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=  29.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  30.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  30.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  30.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  30.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  30.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  30.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   6.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  12.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  57.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  12.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  11.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  57.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  12.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  12.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  57.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  58.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  12.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  57.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  12.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  12.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  58.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  58.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  58.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  12.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  58.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  59.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=  13.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  13.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=  12.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  57.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  58.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  58.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  58.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  58.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time= 1.0min
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time= 1.0min
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time= 1.0min
# ...
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  32.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  31.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  30.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=  30.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  53.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  52.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  52.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  52.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  52.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  52.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  51.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  53.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  51.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  52.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  40.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  42.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  42.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  41.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  43.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  41.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  41.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  40.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  41.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  41.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  40.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  42.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  42.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  41.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  42.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  41.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  40.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  40.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  39.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=  38.1s
# Nested CV MSE: Mean = 0.0070297618242482745, Std = 0.00037769582782701673
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   1.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   1.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   1.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=   3.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=   3.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=   3.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=   3.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=   5.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=   5.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=   6.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=   6.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   1.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   1.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   1.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  11.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  11.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  11.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=   2.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=   2.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=   2.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  11.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  11.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  11.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=   5.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=   4.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=   5.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=   5.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=   5.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=   5.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   1.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   1.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.6; total time=   1.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  10.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  10.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=   9.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=   9.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  10.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=   3.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=   3.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.6; total time=   3.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=   9.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=   5.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=   5.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.6; total time=   5.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=   6.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   1.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   1.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.6; total time=   1.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=500, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  12.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  12.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.6; total time=   3.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, n_estimators=1000, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.6; total time=  14.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  14.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  14.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=1000, subsample=0.8; total time=  14.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=   7.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=   7.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.6; total time=   6.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=   6.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=0.8; total time=   6.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  11.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=  11.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=   9.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.6; total time=   9.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=   9.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=10, n_estimators=1000, subsample=0.8; total time=   9.2s
# Submission file created: (8760, 2)
